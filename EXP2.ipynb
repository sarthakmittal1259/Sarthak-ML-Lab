# %%
print("Hello World")
# Out:
# Hello World

# %%
List = [10, 20, 14]
print("\nList of numbers: ")
print(List)
print("\n ")
print("Accessing a element from the list")
print(List[0])
print(List[2])

List.append(2)
List.append(4)
print("\nList after Addition of two elements: ")
print(List)
# Out:
# List of numbers:
# [10, 20, 14]
#
#
# Accessing a element from the list
# 10
# 14
#
# List after Addition of two elements:
# [10, 20, 14, 2, 4]

# %%
print("Python Dictionaries")
thisdict = {
  "brand": "Mahindra",
  "model": "XUV700",
  "year": 2023
}
print(thisdict)
print("\n")
print("Accesing single value:")
print(thisdict["brand"])
print("\n")
print("Length of dictionary")
print(len(thisdict))
# Out:
# Python Dictionaries
# {'brand': 'Mahindra', 'model': 'XUV700', 'year': 2023}
#
#
# Accesing single value:
# Mahindra
#
#
# Length of dictionary
# 3

# %%
def greet(name):
  print("Hello,", name)

greet("User") # Call the function
# Out:
# Hello, User

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('Lab 1a Sample text file.txt', 'r') as f:
  contents = f.read()
print(contents)
# Out:
# Hello This is my drive file !

# %%
import pandas as pd
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/business-financial-data-march-2024-csv.csv')

# %%
df
# Out:
#      Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0       BDCQ.SF1AA2CA  2016.06    1116.386        NaN      F  Dollars
# 1       BDCQ.SF1AA2CA  2016.09    1070.874        NaN      F  Dollars
# 2       BDCQ.SF1AA2CA  2016.12    1054.408        NaN      F  Dollars
# 3       BDCQ.SF1AA2CA  2017.03    1010.665        NaN      F  Dollars
# 4       BDCQ.SF1AA2CA  2017.06    1233.700        NaN      F  Dollars
# ...               ...      ...         ...        ...    ...      ...
# 7630     BDCQ.SF8RSCA  2023.03     663.630        NaN      F  Dollars
# 7631     BDCQ.SF8RSCA  2023.06     617.507        NaN      F  Dollars
# 7632     BDCQ.SF8RSCA  2023.09     673.068        NaN      F  Dollars
# 7633     BDCQ.SF8RSCA  2023.12     511.098        NaN      F  Dollars
# 7634     BDCQ.SF8RSCA  2024.03     631.229        NaN      F  Dollars
#
#       Magnitude                         Subject  \
# 0             6  Business Data Collection - BDC
# ...

# %%
df_sorted = df.sort_values(by='Data_value', ascending=True)

# %%
df_sorted
# Out:
#      Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 7080    BDCQ.SF8GH2CA  2020.06    -398.194        NaN      F  Dollars
# 7439    BDCQ.SF8PP1CA  2023.06     -35.464        NaN      F  Dollars
# 7471     BDCQ.SF8PPCA  2023.06     -35.464        NaN      F  Dollars
# 7592    BDCQ.SF8RS2CA  2021.09     -17.957        NaN      F  Dollars
# 7587    BDCQ.SF8RS2CA  2020.06      -5.260        NaN      F  Dollars
# ...               ...      ...         ...        ...    ...      ...
# 3835     BDCQ.SF1RSCT  2023.03         NaN        NaN      C  Dollars
# 3836     BDCQ.SF1RSCT  2023.06         NaN        NaN      C  Dollars
# 3837     BDCQ.SF1RSCT  2023.09         NaN        NaN      C  Dollars
# 3838     BDCQ.SF1RSCT  2023.12         NaN        NaN      C  Dollars
# 3839     BDCQ.SF1RSCT  2024.03         NaN        NaN      C  Dollars
#
#       Magnitude                         Subject  \
# 7080          6  Business Data Collection - BDC
# ...

# %%
df.groupby("STATUS").size()
# Out:
# STATUS
# C     698
# F    5069
# R    1868
# dtype: int64

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(df.Data_value,kde=True, color='blue')
plt.title("Data Values")
plt.xlabel('Data_value')
plt.show()

# %%
sns.countplot(data=df,x="STATUS")
# Out:
# <Axes: xlabel='STATUS', ylabel='count'>

# %%
import folium
map_center = [28.75, 77.41]  # Ghaziabad coordinates
my_map = folium.Map(location=map_center, zoom_start=12)
folium.Marker(location=[28.7369552, 77.2806396], popup="Hello, LONI").add_to(my_map)
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
